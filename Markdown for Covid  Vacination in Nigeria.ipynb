# %% [markdown]
# # <font color= green >VACINATION IN NIGERIA</font>

# %% [markdown]
# ### <u> SUMMARY </u>

# %% [markdown]
# Below are graphical representations showing the penetration of covid vacines into the Nigerian populace, from the first day and dose till September 29, 2021.
#
# Anaylsis done with the use of Tableau Public
#
# Data set from National Primary Health Care Development Agency on OpenAfrica [Link](https://africaopendata.org/dataset/covid-19-data)

# %% [markdown]
# #### 1. First Dose By States

# %% [markdown]
# The map below shows the percentage of the population of each states that have received the first dose of the vacine.
#
#
# ![1ST%20dose.png](attachment:1ST%20dose.png)

# %% [markdown]
# As seen above, though lagos has the highest number of vacinated individuals, the FCT has the highest per population

# %% [markdown]
# #### 2. Second Dose By States

# %% [markdown]
# The map below shows the percentage of the population of each states that have received the second dose of the vacine.
#
# ![2nd%20dose.png](attachment:2nd%20dose.png)

# %% [markdown]
# #### 3. Share of States Vacinated

# %% [markdown]
# Below is a pie chart showing the share of the states vacinated with respect to the total population
# ![Vacination%20Population%20By%20State.png](attachment:Vacination%20Population%20By%20State.png)

# %% [markdown]
# #### 4. Regional Treemap

# %% [markdown]
# This treemap shows the population of each region as its size , then the total number of people vacinated in the region as its colour intensity
# ![Treemap%20For%20Vacination%20Density.png](attachment:Treemap%20For%20Vacination%20Density.png)

# %% [markdown]
# #### 5. Dashboard

# %% [markdown]
# A combine dashboard of all the graphical representations
# ![Dashboard1.png](attachment:Dashboard1.png)

# %% [markdown]
# ###### Thank you for your time
#
# *******
